# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -180, high = 180, size = 2000)
cities = []
lat_lngs = []
lat_lngs = zip(lats, lngs)
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for lat_lng in lat_lngs:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        # YOUR CODE HERE

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 770

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime
# Import the OpenWeatherMap's API key

from config1 import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q=" + "London"

requests.get(query_url).json()
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 32.63,
#   'feels_like': 26.31,
#   'temp_min': 29.05,
#   'temp_max': 35.96,
#   'pressure': 1013,
#   'humidity': 86},
#  'visibility': 10000,
#  'wind': {'speed': 6.91, 'deg': 250},
#  'clouds': {'all': 75},
#  'dt': 1674183002,
#  'sys': {'type': 2,
#   'id': 2075535,
#   'country': 'GB',
#   'sunrise': 1674201300,
#   'sunset': 1674232045},
#  'timezone': 0,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
            
        # Append the city information into the city_data list
        # YOUR CODE HERE
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | myingyan
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | severo-kurilsk
# Processing Record 8 of Set 1 | katsuura
# Processing Record 9 of Set 1 | impfondo
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | kushima
# Processing Record 12 of Set 1 | whitehorse
# Processing Record 13 of Set 1 | haines junction
# Processing Record 14 of Set 1 | riyadh
# Processing Record 15 of Set 1 | provideniya
# Processing Record 16 of Set 1 | orocue
# Processing Record 17 of Set 1 | chuy
# Processing Record 18 of Set 1 | pevek
# Processing Record 19 of Set 1 | victoria
# Processing Record 20 of Set 1 | bolungarvik
# Processing Record 21 of Set 1 | lorengau
# Processing Record 22 of Set 1 | saint george
# Processing Record 23 of Set 1 | margate
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | ferkessedougou
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | jiayuguan
# Processing Record 29 of Set 1 | tawkar
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | japura
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | isangel
# Processing Record 35 of Set 1 | sitka
# Processing Record 36 of Set 1 | mao
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | takoradi
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | vargashi
# Processing Record 43 of Set 1 | coquimbo
# Processing Record 44 of Set 1 | louis trichardt
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | northam
# Processing Record 47 of Set 1 | dalbandin
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | toppenish

# %%
city_name = []  # response['name']
lng=[]  # response['coord.lon']
lat=[]  # response['coord.lat']
  # response['timezone']
maxtemp=[]  # response['main.temp']
humidity=[]  # response['main.humidity']
cloudiness=[]  # response['clouds.all']
wind_speed=[]  # response['wind.speed']
country = []
description = []


# create print log to watch progress and errors
print(f"Beginning Data Retrieval \n-------------------------")
for city in cities:
    try:
        query_url = f"{url}appid={weather_api_key}&units={units}&q=" + city
        response = requests.get(query_url).json()
        city_name.append(response['name'])
        lng.append(response['coord']['lon'])
        lat.append(response['coord']['lat'])
        maxtemp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        description.append(response['weather'])
        country.append(response['sys']['country'])
        print(f"Processing Record {cities.index(city)} | {city}")
    except KeyError:
        print('Key Error')
    except ConnectionError:
        print('ConnectionError')
    time.sleep(1)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 0 | bograd
# Key Error
# Processing Record 2 | khatanga
# Processing Record 3 | tautira
# Key Error
# Processing Record 5 | east london
# Key Error
# Processing Record 7 | punta arenas
# Processing Record 8 | oranjemund
# Processing Record 9 | sosenskiy
# Processing Record 10 | srednekolymsk
# Processing Record 11 | maragogi
# Processing Record 12 | sorland
# Processing Record 13 | pevek
# Processing Record 14 | rikitea
# Processing Record 15 | ushuaia
# Key Error
# Processing Record 17 | narsaq
# Processing Record 18 | lagoa
# Processing Record 19 | irbil
# Processing Record 20 | mataura
# Processing Record 21 | hithadhoo
# Processing Record 22 | hobart
# Processing Record 23 | arman
# Key Error
# Processing Record 25 | laguna
# Processing Record 26 | miles city
# Processing Record 27 | rocha
# Processing Record 28 | tuktoyaktuk
# Processing Record 29 | los llanos de aridane
# Processing Record 30 | brazzaville
# Processing Record 31 | albany
# Processing Record 32 | atbasar
# Processing Record 33 | karla
# Processing Record 34 | ponta do sol
# Processing Record 35 | souillac
# Processing Record 36 | mogadishu
# Processing Record 37 | ilulissat
# Processing Record 38 | padang
# Processing Record 39 | nikolskoye
# Processing Record 40 | bethel
# Processing Record 41 | zhangjiakou
# Processing Record 42 | atuona
# Processing Record 43 | husavik
# Processing Record 44 | tiarei
# Processing Record 45 | hualmay
# Processing Record 46 | hermanus
# Processing Record 47 | lavrentiya
# Processing Record 48 | cape town
# Processing Record 49 | bentiu
# Processing Record 50 | vaini
# Processing Record 51 | qaanaaq
# Key Error
# Processing Record 53 | port alfred
# Processing Record 54 | samarai
# Processing Record 55 | cabo san lucas
# Processing Record 56 | talnakh
# Processing Record 57 | bluefield
# Processing Record 58 | jamestown
# Processing Record 59 | matara
# Processing Record 60 | phoenix
# Processing Record 61 | kulhudhuffushi
# Processing Record 62 | kapaa
# Processing Record 63 | torbay
# Processing Record 64 | new norfolk
# Processing Record 65 | saint-philippe
# Processing Record 66 | busselton
# Processing Record 67 | bredasdorp
# Processing Record 68 | barrow
# Processing Record 69 | klaksvik
# Processing Record 70 | tirlyanskiy
# Key Error
# Processing Record 72 | mareeba
# Key Error
# Processing Record 74 | saldanha
# Processing Record 75 | dunedin
# Processing Record 76 | la ronge
# Processing Record 77 | bluff
# Key Error
# Key Error
# Key Error
# Processing Record 81 | kavieng
# Key Error
# Processing Record 83 | ozinki
# Processing Record 84 | port elizabeth
# Processing Record 85 | karuzi
# Processing Record 86 | buala
# Processing Record 87 | kapoeta
# Processing Record 88 | tigil
# Processing Record 89 | gardenstown
# Processing Record 90 | ahipara
# Processing Record 91 | morgan city
# Processing Record 92 | georgetown
# Processing Record 93 | luderitz
# Key Error
# Processing Record 95 | cockburn town
# Processing Record 96 | okhotsk
# Processing Record 97 | sur
# Processing Record 98 | baoshan
# Processing Record 99 | anadyr
# Processing Record 100 | kodiak
# Processing Record 101 | fort morgan
# Processing Record 102 | constitucion
# Key Error
# Processing Record 104 | haines junction
# Processing Record 105 | tiksi
# Processing Record 106 | hilo
# Processing Record 107 | sao filipe
# Processing Record 108 | puerto ayora
# Processing Record 109 | tual
# Key Error
# Processing Record 111 | arraial do cabo
# Key Error
# Processing Record 113 | bansang
# Processing Record 114 | coquimbo
# Processing Record 115 | saint anthony
# Processing Record 116 | grindavik
# Processing Record 117 | yellowknife
# Processing Record 118 | yumen
# Processing Record 119 | zemio
# Processing Record 120 | lebu
# Processing Record 121 | ribeira grande
# Processing Record 122 | kutum
# Processing Record 123 | garissa
# Processing Record 124 | abu samrah
# Processing Record 125 | kavaratti
# Processing Record 126 | brigantine
# Processing Record 127 | lamu
# Processing Record 128 | gamba
# Processing Record 129 | aklavik
# Processing Record 130 | mazamari
# Processing Record 131 | shenjiamen
# Processing Record 132 | vestmannaeyjar
# Processing Record 133 | cherskiy
# Processing Record 134 | pangnirtung
# Processing Record 135 | qaqortoq
# Processing Record 136 | rognan
# Processing Record 137 | kaeo
# Processing Record 138 | cidreira
# Processing Record 139 | dikson
# Processing Record 140 | oxbow
# Processing Record 141 | zalalovo
# Processing Record 142 | tasiilaq
# Processing Record 143 | mokhsogollokh
# Processing Record 144 | chuy
# Key Error
# Processing Record 146 | san patricio
# Processing Record 147 | north bend
# Processing Record 148 | denpasar
# Processing Record 149 | mutoko
# Processing Record 150 | nampula
# Processing Record 151 | pisco
# Processing Record 152 | bathsheba
# Processing Record 153 | nome
# Processing Record 154 | port lincoln
# Processing Record 155 | severo-kurilsk
# Processing Record 156 | norman wells
# Processing Record 157 | pemba
# Processing Record 158 | dwarka
# Processing Record 159 | mulchen
# Key Error
# Processing Record 161 | sorong
# Key Error
# Processing Record 163 | lamesa
# Processing Record 164 | avarua
# Processing Record 165 | colomba
# Processing Record 166 | fairbanks
# Processing Record 167 | tambopata
# Processing Record 168 | sistranda
# Processing Record 169 | chara
# Processing Record 170 | alekseyevsk
# Processing Record 171 | kirakira
# Processing Record 172 | roald
# Processing Record 173 | broken hill
# Processing Record 174 | thessalon
# Processing Record 175 | iqaluit
# Processing Record 176 | emerald
# Processing Record 177 | joshimath
# Processing Record 178 | touros
# Processing Record 179 | bilibino
# Processing Record 180 | flic en flac
# Processing Record 181 | formosa
# Processing Record 182 | mahebourg
# Processing Record 183 | kaitangata
# Processing Record 184 | ibipeba
# Processing Record 185 | jinka
# Processing Record 186 | sabzevar
# Processing Record 187 | fallon
# Processing Record 188 | simpang
# Processing Record 189 | ati
# Processing Record 190 | flinders
# Processing Record 191 | hervey bay
# Processing Record 192 | mount isa
# Processing Record 193 | cap malheureux
# Processing Record 194 | komsomolskiy
# Processing Record 195 | carnarvon
# Processing Record 196 | castro
# Processing Record 197 | ekibastuz
# Processing Record 198 | vila franca do campo
# Processing Record 199 | fare
# Key Error
# Processing Record 201 | leningradskiy
# Processing Record 202 | urengoy
# Processing Record 203 | hami
# Processing Record 204 | hay river
# Processing Record 205 | volksrust
# Processing Record 206 | itagi
# Processing Record 207 | tazovskiy
# Processing Record 208 | victoria
# Processing Record 209 | ostrovnoy
# Processing Record 210 | pitimbu
# Processing Record 211 | sarh
# Processing Record 212 | nacala
# Processing Record 213 | lakes entrance
# Processing Record 214 | gloucester
# Processing Record 215 | chumikan
# Processing Record 216 | sucua
# Processing Record 217 | adrar
# Processing Record 218 | monteroni di lecce
# Processing Record 219 | byron bay
# Key Error
# Processing Record 221 | sakakah
# Key Error
# Processing Record 223 | fortuna
# Processing Record 224 | meulaboh
# Processing Record 225 | kabinda
# Processing Record 226 | ipixuna
# Processing Record 227 | toamasina
# Processing Record 228 | severnyy
# Processing Record 229 | college
# Processing Record 230 | daru
# Key Error
# Processing Record 232 | teeli
# Processing Record 233 | koslan
# Processing Record 234 | pochutla
# Processing Record 235 | saint george
# Processing Record 236 | kidal
# Processing Record 237 | shimoda
# Processing Record 238 | faanui
# Processing Record 239 | saskylakh
# Processing Record 240 | wajir
# Processing Record 241 | skibbereen
# Processing Record 242 | wattegama
# Processing Record 243 | thompson
# Key Error
# Processing Record 245 | jalu
# Processing Record 246 | sirmaur
# Processing Record 247 | eureka
# Processing Record 248 | kibondo
# Processing Record 249 | puerto madryn
# Processing Record 250 | mehamn
# Processing Record 251 | sibolga
# Processing Record 252 | longyearbyen
# Processing Record 253 | nianzishan
# Processing Record 254 | thinadhoo
# Processing Record 255 | killybegs
# Processing Record 256 | tuatapere
# Key Error
# Processing Record 258 | balkhash
# Processing Record 259 | motril
# Processing Record 260 | lazeshchyna
# Key Error
# Processing Record 262 | hirara
# Processing Record 263 | kongolo
# Processing Record 264 | dhidhdhoo
# Processing Record 265 | milkovo
# Processing Record 266 | suez
# Processing Record 267 | ondjiva
# Processing Record 268 | omboue
# Key Error
# Processing Record 270 | bulawayo
# Processing Record 271 | bad hofgastein
# Processing Record 272 | gambela
# Processing Record 273 | leninskoye
# Key Error
# Processing Record 275 | hofn
# Processing Record 276 | tocopilla
# Processing Record 277 | sardarshahr
# Processing Record 278 | tshikapa
# Processing Record 279 | kitimat
# Processing Record 280 | alamosa
# Key Error
# Processing Record 282 | upernavik
# Processing Record 283 | butaritari
# Processing Record 284 | batagay-alyta
# Processing Record 285 | atar
# Processing Record 286 | phonhong
# Key Error
# Processing Record 288 | harnoli
# Processing Record 289 | matveyevka
# Processing Record 290 | hasaki
# Processing Record 291 | bagdarin
# Processing Record 292 | luanda
# Processing Record 293 | temiscaming
# Processing Record 294 | erzin
# Processing Record 295 | riohacha
# Processing Record 296 | bengkulu
# Processing Record 297 | biak
# Processing Record 298 | kerema
# Processing Record 299 | catuday
# Processing Record 300 | ilebo
# Processing Record 301 | mount gambier
# Processing Record 302 | salinopolis
# Processing Record 303 | chapais
# Processing Record 304 | inuvik
# Processing Record 305 | sioux lookout
# Processing Record 306 | romitan
# Processing Record 307 | udachnyy
# Processing Record 308 | nabire
# Processing Record 309 | chimbote
# Processing Record 310 | noumea
# Processing Record 311 | conceicao do araguaia
# Processing Record 312 | vostok
# Key Error
# Processing Record 314 | port hardy
# Processing Record 315 | portland
# Processing Record 316 | bubaque
# Processing Record 317 | guilin
# Processing Record 318 | kloulklubed
# Processing Record 319 | blagoyevo
# Processing Record 320 | lebanon
# Key Error
# Processing Record 322 | namibe
# Processing Record 323 | chokurdakh
# Processing Record 324 | pala
# Processing Record 325 | roma
# Processing Record 326 | lumsden
# Processing Record 327 | muravlenko
# Processing Record 328 | barcelona
# Processing Record 329 | marystown
# Processing Record 330 | tura
# Processing Record 331 | provideniya
# Processing Record 332 | kruisfontein
# Processing Record 333 | hovd
# Processing Record 334 | vila velha
# Processing Record 335 | abalak
# Processing Record 336 | bousso
# Processing Record 337 | zlitan
# Processing Record 338 | luganville
# Processing Record 339 | vila
# Key Error
# Processing Record 341 | turan
# Processing Record 342 | edgewater
# Processing Record 343 | yuzhno-kurilsk
# Processing Record 344 | orlik
# Processing Record 345 | pemangkat
# Processing Record 346 | juegang
# Processing Record 347 | codrington
# Processing Record 348 | lakatoro
# Processing Record 349 | garmsar
# Processing Record 350 | beloha
# Processing Record 351 | batticaloa
# Processing Record 352 | lipno
# Processing Record 353 | healesville
# Processing Record 354 | vanersborg
# Processing Record 355 | moron
# Processing Record 356 | nuuk
# Processing Record 357 | luau
# Processing Record 358 | alofi
# Processing Record 359 | mirante do paranapanema
# Processing Record 360 | richards bay
# Processing Record 361 | jackson
# Processing Record 362 | taganak
# Processing Record 363 | ciudad bolivar
# Processing Record 364 | leshukonskoye
# Processing Record 365 | fujin
# Processing Record 366 | geraldton
# Processing Record 367 | sturgeon falls
# Processing Record 368 | piney green
# Processing Record 369 | monte patria
# Processing Record 370 | reconquista
# Processing Record 371 | ormara
# Processing Record 372 | saint-augustin
# Processing Record 373 | san carlos de bariloche
# Processing Record 374 | bonnyville
# Processing Record 375 | sydney
# Processing Record 376 | isangel
# Processing Record 377 | inhambane
# Processing Record 378 | odweyne
# Processing Record 379 | margate
# Key Error
# Processing Record 381 | namtsy
# Processing Record 382 | bereda
# Processing Record 383 | kerouane
# Processing Record 384 | rorvik
# Processing Record 385 | bakchar
# Processing Record 386 | sabang
# Processing Record 387 | risti
# Processing Record 388 | san policarpo
# Processing Record 389 | lusambo
# Processing Record 390 | tabou
# Processing Record 391 | muros
# Key Error
# Key Error
# Processing Record 394 | abu zabad
# Processing Record 395 | marrakesh
# Processing Record 396 | manbij
# Processing Record 397 | luwuk
# Processing Record 398 | gayeri
# Processing Record 399 | prince rupert
# Processing Record 400 | vilcun
# Processing Record 401 | jiehu
# Processing Record 402 | smirnykh
# Processing Record 403 | katsuura
# Processing Record 404 | kahului
# Processing Record 405 | yulara
# Processing Record 406 | pokhara
# Processing Record 407 | jiquipilas
# Processing Record 408 | clyde river
# Processing Record 409 | palenque
# Processing Record 410 | qingquan
# Processing Record 411 | dolores
# Processing Record 412 | lincoln
# Processing Record 413 | san isidro
# Processing Record 414 | beidao
# Processing Record 415 | galesong
# Processing Record 416 | vicuna
# Key Error
# Processing Record 418 | penzance
# Processing Record 419 | tagusao
# Processing Record 420 | ketchikan
# Processing Record 421 | seoul
# Processing Record 422 | virginia beach
# Processing Record 423 | bang saphan
# Processing Record 424 | ashtian
# Processing Record 425 | vieste
# Processing Record 426 | port-cartier
# Processing Record 427 | blyth
# Processing Record 428 | bintulu
# Processing Record 429 | coahuayana
# Processing Record 430 | qiongshan
# Key Error
# Processing Record 432 | puerto escondido
# Processing Record 433 | ape
# Processing Record 434 | mackay
# Processing Record 435 | jacmel
# Processing Record 436 | airai
# Processing Record 437 | coruripe
# Processing Record 438 | visim
# Processing Record 439 | angoche
# Processing Record 440 | mahon
# Processing Record 441 | faridkot

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame({'name': city_name, "country": country,'latitude':lat,'longitude': lng, 'max temperature': maxtemp,
"humidity": humidity, "cloudiness": cloudiness, "wind speed": wind_speed, "current description": description})

city_data_df.head()
# Out:
#            name  longitude  latitude  max temperature  wind speed  \
# 0        Bograd    90.8328   54.2344             8.92        5.68
# 1      Khatanga   102.5000   71.9667           -43.56        3.80
# 2       Tautira  -149.1500  -17.7333            81.10       14.34
# 3   East London    27.9116  -33.0153            72.05       10.00
# 4  Punta Arenas   -70.9167  -53.1500            51.91        5.75
#
#                                  current description  cloudiness
# 0  [{'id': 600, 'main': 'Snow', 'description': 'l...         100
# 1  [{'id': 801, 'main': 'Clouds', 'description': ...          23
# 2  [{'id': 802, 'main': 'Clouds', 'description': ...          28
# 3  [{'id': 804, 'main': 'Clouds', 'description': ...          93
# 4  [{'id': 800, 'main': 'Clear', 'description': '...           0

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0            Bluff -46.6000  168.3333     56.80          few clouds        68
# 1            Metro  -5.1131  105.3067     88.48     overcast clouds        54
# 2    Pacific Grove  36.6177 -121.9166     64.08           clear sky        87
# 3     Saint George  37.1041 -113.5841     79.95           clear sky        40
# 4          Mataura -46.1927  168.8643     56.48          few clouds        56
# 5          Biltine  14.5333   20.9167     80.42    scattered clouds        61
# 6              Gao  16.6362    1.6370     85.73       broken clouds        47
# 7        Hithadhoo  -0.6000   73.0833     82.00    scattered clouds        72
# 8  Bambous Virieux -20.3428   57.7575     76.21       broken clouds        78
# 9          Rikitea -23.1203 -134.9692     73.35           clear sky        72
#
#    Cloudiness  Wind Speed Country
# 0          21        2.28      NZ
# 1          92        4.52      ID
# 2           0        4.61      US
# 3           0       10.36      US
# 4          15        2.44      NZ
# 5          27        3.36      TD
# 6          77        6.31      ML
# 7          47        7.78      MV
# 8          75       13.80      MU
# 9           3       14.23      PF

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff      NZ -46.6000  168.3333     56.80        68          21
# 1            Metro      ID  -5.1131  105.3067     88.48        54          92
# 2    Pacific Grove      US  36.6177 -121.9166     64.08        87           0
# 3     Saint George      US  37.1041 -113.5841     79.95        40           0
# 4          Mataura      NZ -46.1927  168.8643     56.48        56          15
# 5          Biltine      TD  14.5333   20.9167     80.42        61          27
# 6              Gao      ML  16.6362    1.6370     85.73        47          77
# 7        Hithadhoo      MV  -0.6000   73.0833     82.00        72          47
# 8  Bambous Virieux      MU -20.3428   57.7575     76.21        78          75
# 9          Rikitea      PF -23.1203 -134.9692     73.35        72           3
#
#    Wind Speed Current Description
# 0        2.28          few clouds
# 1        4.52     overcast clouds
# 2        4.61           clear sky
# 3       10.36           clear sky
# 4        2.44          few clouds
# 5        3.36    scattered clouds
# 6        6.31       broken clouds
# 7        7.78    scattered clouds
# 8       13.80       broken clouds
# 9       14.23           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
